# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")
df.head(2)
# Out:
#    FechaCorte    NumeroRuc  FechaOrden  NumeroOrden CodigoGenerico  \
# 0    20240425  20536547976    20240202            1            B17
# 1    20240425  10438105862    20240202            2            B71
#
#                        DescripcionGenerico     Importe  ExpedienteSiaf  \
# 0  COMBUSTIBLES, CARBURANTES Y LUBRICANTES  392,168.00             515
# 1             OFICINA: UTILES Y MATERIALES    4,500.00             637
#
#                                FuenteFinanciamiento  EspecificoGasto  \
# 0  18 CANON Y SOBRECANON, REGALIAS,RENTA DE ADUANAS           231311
# 1  18 CANON Y SOBRECANON, REGALIAS,RENTA DE ADUANAS           231512
#
#                           DescripcionEspecificoGasto   Cantidad TipoBien  \
# 0                         COMBUSTIBLES Y CARBURANTES  22,538.39        B
# 1  PAPELERIA EN GENERAL, UTILES Y MATERIALES DE O...   1,500.00        B
#
#   TipoRecurso                                    FuncionPrograma  MetaSiaf  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3352 entries, 0 to 3351
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   FechaCorte                  3352 non-null   int64
#  1   NumeroRuc                   3352 non-null   int64
#  2   FechaOrden                  3352 non-null   int64
#  3   NumeroOrden                 3352 non-null   int64
#  4   CodigoGenerico              3352 non-null   object
#  5   DescripcionGenerico         3352 non-null   object
#  6   Importe                     3352 non-null   object
#  7   ExpedienteSiaf              3352 non-null   int64
#  8   FuenteFinanciamiento        3352 non-null   object
#  9   EspecificoGasto             3352 non-null   int64
#  10  DescripcionEspecificoGasto  3352 non-null   object
#  11  Cantidad                    3352 non-null   object
#  12  TipoBien                    3352 non-null   object
# ...

# %%
# Renombrar columnas PascalCase
nuevos_nombres = {
            'FechaCorte': 'fecha_corte',
            'NumeroRuc': 'numero_ruc',
            'FechaOrden': 'fecha_orden',
            'NumeroOrden': 'numero_orden',
            'CodigoGenerico': 'codigo_generico',
            'DescripcionGenerico': 'descripcion_generico',
            'Importe': 'importe',
            'ExpedienteSiaf': 'expediente_siaf',
            'FuenteFinanciamiento': 'fuente_financiamiento',
            'EspecificoGasto': 'especifico_gasto',
            'DescripcionEspecificoGasto': 'descripcion_especifico_gasto',
            'Cantidad': 'cantidad',
            'TipoBien': 'tipo_bien',
            'TipoRecurso': 'tipo_recurso',
            'FuncionPrograma': 'funcion_programa',
            'MetaSiaf': 'meta_siaf',
            'Programa': 'programa',
            'Subprograma': 'subprograma'

}

df = df.rename(columns=nuevos_nombres)

# %%
#como exportar el dataframe a un csv
df.to_csv("data.csv", index=False)

# %%
df.head(2)
# Out:
#    fecha_corte   numero_ruc  fecha_orden  numero_orden codigo_generico  \
# 0     20240425  20536547976     20240202             1             B17
# 1     20240425  10438105862     20240202             2             B71
#
#                       descripcion_generico     importe  expediente_siaf  \
# 0  COMBUSTIBLES, CARBURANTES Y LUBRICANTES  392,168.00              515
# 1             OFICINA: UTILES Y MATERIALES    4,500.00              637
#
#                               fuente_financiamiento  especifico_gasto  \
# 0  18 CANON Y SOBRECANON, REGALIAS,RENTA DE ADUANAS            231311
# 1  18 CANON Y SOBRECANON, REGALIAS,RENTA DE ADUANAS            231512
#
#                         descripcion_especifico_gasto   cantidad tipo_bien  \
# 0                         COMBUSTIBLES Y CARBURANTES  22,538.39         B
# 1  PAPELERIA EN GENERAL, UTILES Y MATERIALES DE O...   1,500.00         B
#
#   tipo_recurso                                   funcion_programa  meta_siaf  \
# ...
